# %%
# Setup and Imports
import pandas as pd
import requests
import h3
import time
from typing import Dict, Tuple
from datetime import datetime

# %%
# Configuration
API_KEY = ""  # Replace with your Google Maps API key
INPUT_FILE = "Output/Updated_RDO No. 49 - North Makati City.xlsx"  # Replace with your file name
H3_RESOLUTION = 9  # Adjust resolution as needed (0-15)

# %%
# Read the Excel file
df = pd.read_excel(INPUT_FILE)
print("Data loaded successfully!")
print(f"Number of addresses to process: {len(df)}")
df.head()
# Out:
# Data loaded successfully!
# Number of addresses to process: 939
#   Province City/Municipality Barangay Street/Subdivision  \
# 0      NCR       MAKATI CITY  BEL-AIR            AMAPOLA
# 1      NCR       MAKATI CITY  BEL-AIR            ANTARES
# 2      NCR       MAKATI CITY  BEL-AIR               ANZA
# 3      NCR       MAKATI CITY  BEL-AIR           AQUARIUS
# 4      NCR       MAKATI CITY  BEL-AIR              ARIES
#
#                 Vicinity Classification    ZV/SQM
# 0    Estrella - Mercedes             RR  250000.0
# 1     Jupiter - Mercedes             RR  250000.0
# 2  Makati Ave. - Polaris             CR  350000.0
# 3          Hydra - Solar             RR  250000.0
# 4      Mercedes - Taurus             RR  250000.0

# %%
small_df = df.sample(n=3).copy()
small_df
# Out:
#     Province City/Municipality         Barangay Street/Subdivision  \
# 453      NCR       MAKATI CITY        POBLACION    AMORSOLO SQUARE
# 603      NCR       MAKATI CITY      SAN ANTONIO           ANUBBING
# 155      NCR       MAKATI CITY  GUADALUPE VIEJO       1 PROSCENIUM
#
#                                            Vicinity Classification    ZV/SQM
# 453                 Amorsolo Drive, Rockwell Center             CC  300000.0
# 603                              Mayapis - Kamagong             CR  100000.0
# 155  The Proscenium, Rockwell, Dr Jose P. Rizal Ave             CC  300000.0

# %%
# Function to format address
def format_address(row: pd.Series) -> str:
    """Format address components into a single string"""
    components = []
    if pd.notna(row.get('Street/Subdivision')):
        components.append(str(row['Street/Subdivision']))
    if pd.notna(row.get('Barangay')):
        components.append(f"{row['Barangay']}")
    if pd.notna(row.get('City/Municipality')):
        components.append(str(row['City/Municipality']))
    if pd.notna(row.get('Province')):
        components.append(str(row['Province']))
    components.append('Philippines')
    return ", ".join(components)

# Test address formatting with first row
test_address = format_address(df.iloc[0])
print("Sample formatted address:", test_address)
# Out:
# Sample formatted address: AMAPOLA, BEL-AIR, MAKATI CITY, NCR, Philippines

# %%
# Function to geocode address
def geocode_address(address: str, api_key: str) -> Tuple[float, float, Dict]:
    """Geocode address using Google's Geocoding API"""
    url = "https://maps.googleapis.com/maps/api/geocode/json"
    params = {
        'address': address,
        'key': api_key,
        'region': 'ph'
    }
    
    response = requests.get(url, params=params)
    data = response.json()
    
    if data['status'] == 'OK':
        location = data['results'][0]['geometry']['location']
        return location['lat'], location['lng'], data['results'][0]
    else:
        raise Exception(f"Geocoding failed: {data['status']}")

# Test geocoding with sample address
try:
    lat, lng, data = geocode_address(test_address, API_KEY)
    print(f"Test geocoding successful!")
    print(f"Latitude: {lat}")
    print(f"Longitude: {lng}")
    print(f"Formatted Address: {data['formatted_address']}")
except Exception as e:
    print(f"Test geocoding failed: {str(e)}")

# %%
# Function to get H3 index
def get_h3_index(lat: float, lng: float, resolution: int = 9) -> str:
    """Convert coordinates to H3 index"""
    return h3.latlng_to_cell(lat, lng, resolution)

# %%
# Process all addresses
results = []

for idx, row in df.iterrows():
    try:
        address = format_address(row)
        print(f"Processing {idx + 1}/{len(df)}: {address}")
        
        # Add delay to respect API rate limits
        time.sleep(0.1)
        
        lat, lng, google_data = geocode_address(address, API_KEY)
        h3_index = get_h3_index(lat, lng, H3_RESOLUTION)
        
        results.append({
            'original_address': address,
            'latitude': lat,
            'longitude': lng,
            'h3_index': h3_index,
            'google_formatted_address': google_data['formatted_address'],
            'google_place_id': google_data['place_id'],
            'google_location_type': google_data['geometry']['location_type']
        })
        
    except Exception as e:
        print(f"Error processing row {idx}: {str(e)}")
        results.append({
            'original_address': address,
            'error': str(e)
        })
# Out:
# Processing 1/939: AMAPOLA, BEL-AIR, MAKATI CITY, NCR, Philippines
# Processing 2/939: ANTARES, BEL-AIR, MAKATI CITY, NCR, Philippines
# Processing 3/939: ANZA, BEL-AIR, MAKATI CITY, NCR, Philippines
# Processing 4/939: AQUARIUS, BEL-AIR, MAKATI CITY, NCR, Philippines
# Processing 5/939: ARIES, BEL-AIR, MAKATI CITY, NCR, Philippines
# Processing 6/939: ASTEROID, BEL-AIR, MAKATI CITY, NCR, Philippines
# Processing 7/939: ASTRA I, BEL-AIR, MAKATI CITY, NCR, Philippines
# Processing 8/939: AYALA AVENUE (EXTENSION)***, BEL-AIR, MAKATI CITY, NCR, Philippines
# Processing 9/939: CANOPUS, BEL-AIR, MAKATI CITY, NCR, Philippines
# Processing 10/939: COMET, BEL-AIR, MAKATI CITY, NCR, Philippines
# Processing 11/939: CONSTELLATION, BEL-AIR, MAKATI CITY, NCR, Philippines
# Processing 12/939: ESTRELLA, BEL-AIR, MAKATI CITY, NCR, Philippines
# Processing 13/939: GALAXY, BEL-AIR, MAKATI CITY, NCR, Philippines
# Processing 14/939: HERCULES, BEL-AIR, MAKATI CITY, NCR, Philippines
# Processing 15/939: HYDRA, BEL-AIR, MAKATI CITY, NCR, Philippines
# Processing 16/939: JUNO, BEL-AIR, MAKATI CITY, NCR, Philippines
# Processing 17/939: JUPITER, BEL-AIR, MAKATI CITY, NCR, Philippines
# Processing 18/939: LEO, BEL-AIR, MAKATI CITY, NCR, Philippines
# Processing 19/939: LIBRA, BEL-AIR, MAKATI CITY, NCR, Philippines
# Processing 20/939: MAKATI AVENUE, BEL-AIR, MAKATI CITY, NCR, Philippines
# Processing 21/939: MAKATI AVENUE, BEL-AIR, MAKATI CITY, NCR, Philippines
# Processing 22/939: MAKATI AVENUE, BEL-AIR, MAKATI CITY, NCR, Philippines
# Processing 23/939: MALUGAY, BEL-AIR, MAKATI CITY, NCR, Philippines
# Processing 24/939: MARS, BEL-AIR, MAKATI CITY, NCR, Philippines
# Processing 25/939: MERCEDES, BEL-AIR, MAKATI CITY, NCR, Philippines
# Processing 26/939: MERCURY, BEL-AIR, MAKATI CITY, NCR, Philippines
# Processing 27/939: N. GARCIA (REPOSO), BEL-AIR, MAKATI CITY, NCR, Philippines
# Processing 28/939: N. GARCIA (REPOSO), BEL-AIR, MAKATI CITY, NCR, Philippines
# Processing 29/939: N. GARCIA (REPOSO), BEL-AIR, MAKATI CITY, NCR, Philippines
# Processing 30/939: NEPTUNE, BEL-AIR, MAKATI CITY, NCR, Philippines
# Processing 31/939: NEPTUNE, BEL-AIR, MAKATI CITY, NCR, Philippines
# Processing 32/939: ORBIT, BEL-AIR, MAKATI CITY, NCR, Philippines
# Processing 33/939: ORION, BEL-AIR, MAKATI CITY, NCR, Philippines
# Processing 34/939: PLANET, BEL-AIR, MAKATI CITY, NCR, Philippines
# Processing 35/939: POLARIS, BEL-AIR, MAKATI CITY, NCR, Philippines
# Processing 36/939: POLARIS, BEL-AIR, MAKATI CITY, NCR, Philippines
# Processing 37/939: SATURN, BEL-AIR, MAKATI CITY, NCR, Philippines
# Processing 38/939: SEN. GIL PUYAT, BEL-AIR, MAKATI CITY, NCR, Philippines
# Processing 39/939: SEN. GIL PUYAT, BEL-AIR, MAKATI CITY, NCR, Philippines
# Processing 40/939: SOLAR, BEL-AIR, MAKATI CITY, NCR, Philippines
# Processing 41/939: STELLA, BEL-AIR, MAKATI CITY, NCR, Philippines
# Processing 42/939: TAURUS, BEL-AIR, MAKATI CITY, NCR, Philippines
# Processing 43/939: ZODIAC, BEL-AIR, MAKATI CITY, NCR, Philippines
# Processing 44/939: ZODIAC, BEL-AIR, MAKATI CITY, NCR, Philippines
# Processing 45/939: ALPHA LAND, BEL-AIR, MAKATI CITY, NCR, Philippines
# Processing 46/939: ALPHA LAND, BEL-AIR, MAKATI CITY, NCR, Philippines
# Processing 47/939: ALPHA LAND, BEL-AIR, MAKATI CITY, NCR, Philippines
# Processing 48/939: AIR RESIDENCES / SMDC, BEL-AIR, MAKATI CITY, NCR, Philippines
# Processing 49/939: AIR RESIDENCES / SMDC, BEL-AIR, MAKATI CITY, NCR, Philippines
# Processing 50/939: AIR RESIDENCES / SMDC, BEL-AIR, MAKATI CITY, NCR, Philippines
# Processing 51/939: KROMA TOWER / ALVEO, BEL-AIR, MAKATI CITY, NCR, Philippines
# Processing 52/939: KROMA TOWER / ALVEO, BEL-AIR, MAKATI CITY, NCR, Philippines
# Processing 53/939: KROMA TOWER / ALVEO, BEL-AIR, MAKATI CITY, NCR, Philippines
# Processing 54/939: CEO FLATS, BEL-AIR, MAKATI CITY, NCR, Philippines
# Processing 55/939: CEO FLATS, BEL-AIR, MAKATI CITY, NCR, Philippines
# Processing 56/939: CEO FLATS, BEL-AIR, MAKATI CITY, NCR, Philippines
# Processing 57/939: ENZO BUILDING, BEL-AIR, MAKATI CITY, NCR, Philippines
# Processing 58/939: ENZO BUILDING, BEL-AIR, MAKATI CITY, NCR, Philippines
# Processing 59/939: ENZO BUILDING, BEL-AIR, MAKATI CITY, NCR, Philippines
# Processing 60/939: A. P.  REYES, CARMONA, MAKATI CITY, NCR, Philippines
# Processing 61/939: A. P.  REYES, CARMONA, MAKATI CITY, NCR, Philippines
# Processing 62/939: ARPILLEDA, CARMONA, MAKATI CITY, NCR, Philippines
# Processing 63/939: CRYSTAL, CARMONA, MAKATI CITY, NCR, Philippines
# Processing 64/939: D. BENITO, CARMONA, MAKATI CITY, NCR, Philippines
# Processing 65/939: DIZON, CARMONA, MAKATI CITY, NCR, Philippines
# Processing 66/939: E. PASCUA, CARMONA, MAKATI CITY, NCR, Philippines
# Processing 67/939: E. PASCUA, CARMONA, MAKATI CITY, NCR, Philippines
# Processing 68/939: ESTRELLA, CARMONA, MAKATI CITY, NCR, Philippines
# Processing 69/939: GUIZON / F. GUIZON, CARMONA, MAKATI CITY, NCR, Philippines
# Processing 70/939: H. SANTOS, CARMONA, MAKATI CITY, NCR, Philippines
# Processing 71/939: HIPODROMO, CARMONA, MAKATI CITY, NCR, Philippines
# Processing 72/939: MENDOZA, CARMONA, MAKATI CITY, NCR, Philippines
# Processing 73/939: P. DOMINGO, CARMONA, MAKATI CITY, NCR, Philippines
# Processing 74/939: P. NUNEZ, CARMONA, MAKATI CITY, NCR, Philippines
# Processing 75/939: PERRY, CARMONA, MAKATI CITY, NCR, Philippines
# Processing 76/939: RODIL, CARMONA, MAKATI CITY, NCR, Philippines
# Processing 77/939: RODRIGUEZ, CARMONA, MAKATI CITY, NCR, Philippines
# Processing 78/939: J. MAGSAYSAY, CARMONA, MAKATI CITY, NCR, Philippines
# Processing 79/939: J. MAGSAYSAY, CARMONA, MAKATI CITY, NCR, Philippines
# Processing 80/939: THE SOLSTICE TOWER, CARMONA, MAKATI CITY, NCR, Philippines
# Processing 81/939: THE SOLSTICE TOWER, CARMONA, MAKATI CITY, NCR, Philippines
# Processing 82/939: THE SOLSTICE TOWER, CARMONA, MAKATI CITY, NCR, Philippines
# Processing 83/939: THE STILES ENTERPRISE PLAZA-EAST TOWER, CARMONA, MAKATI CITY, NCR, Philippines
# Processing 84/939: THE STILES ENTERPRISE PLAZA-EAST TOWER, CARMONA, MAKATI CITY, NCR, Philippines
# Processing 85/939: THE STILES ENTERPRISE PLAZA-EAST TOWER, CARMONA, MAKATI CITY, NCR, Philippines
# Processing 86/939: CALLISTO TOWER 1, CARMONA, MAKATI CITY, NCR, Philippines
# Processing 87/939: CALLISTO TOWER 1, CARMONA, MAKATI CITY, NCR, Philippines
# Processing 88/939: CALLISTO TOWER 1, CARMONA, MAKATI CITY, NCR, Philippines
# Processing 89/939: CALLISTO TOWER 2, CARMONA, MAKATI CITY, NCR, Philippines
# Processing 90/939: CALLISTO TOWER 2, CARMONA, MAKATI CITY, NCR, Philippines
# Processing 91/939: CALLISTO TOWER 2, CARMONA, MAKATI CITY, NCR, Philippines
# Processing 92/939: ADALLA, GUADALUPE VIEJO, MAKATI CITY, NCR, Philippines
# Processing 150/939: WEST GARDEN VILLA - PROSCENIUM**, GUADALUPE VIEJO, MAKATI CITY, NCR, Philippines
# Processing 151/939: WEST GARDEN VILLA - PROSCENIUM**, GUADALUPE VIEJO, MAKATI CITY, NCR, Philippines
# Processing 152/939: EL TOWER CONDOMINIUM, GUADALUPE VIEJO, MAKATI CITY, NCR, Philippines
# Processing 153/939: EL TOWER CONDOMINIUM, GUADALUPE VIEJO, MAKATI CITY, NCR, Philippines
# Processing 154/939: EL TOWER CONDOMINIUM, GUADALUPE VIEJO, MAKATI CITY, NCR, Philippines
# Processing 155/939: 1 PROSCENIUM, GUADALUPE VIEJO, MAKATI CITY, NCR, Philippines
# Processing 156/939: 1 PROSCENIUM, GUADALUPE VIEJO, MAKATI CITY, NCR, Philippines
# Processing 157/939: 1 PROSCENIUM, GUADALUPE VIEJO, MAKATI CITY, NCR, Philippines
# Processing 158/939: VILLAS DE GUADALUPE, GUADALUPE VIEJO, MAKATI CITY, NCR, Philippines
# Processing 159/939: VILLAS DE GUADALUPE, GUADALUPE VIEJO, MAKATI CITY, NCR, Philippines
# Processing 160/939: VILLAS DE GUADALUPE, GUADALUPE VIEJO, MAKATI CITY, NCR, Philippines
# Processing 161/939: BENITEZ, KASILAWAN, MAKATI CITY, NCR, Philippines
# Processing 162/939: D. BENITO, KASILAWAN, MAKATI CITY, NCR, Philippines
# Processing 163/939: C - 8, KASILAWAN, MAKATI CITY, NCR, Philippines
# Processing 164/939: C - 9, KASILAWAN, MAKATI CITY, NCR, Philippines
# Processing 165/939: C - 10, KASILAWAN, MAKATI CITY, NCR, Philippines
# Processing 166/939: CAGAYAN, KASILAWAN, MAKATI CITY, NCR, Philippines
# Processing 167/939: CARIDAD, KASILAWAN, MAKATI CITY, NCR, Philippines
# Processing 168/939: DEL PAN, KASILAWAN, MAKATI CITY, NCR, Philippines
# Processing 169/939: E. GUIZON, KASILAWAN, MAKATI CITY, NCR, Philippines
# Processing 170/939: E. PASCUA, KASILAWAN, MAKATI CITY, NCR, Philippines
# Processing 171/939: E. PASCUA, KASILAWAN, MAKATI CITY, NCR, Philippines
# Processing 172/939: ESPERANZA, KASILAWAN, MAKATI CITY, NCR, Philippines
# Processing 173/939: EVANGELISTA, KASILAWAN, MAKATI CITY, NCR, Philippines
# Processing 174/939: FRANCISCO, KASILAWAN, MAKATI CITY, NCR, Philippines
# Processing 175/939: H. SANTOS, KASILAWAN, MAKATI CITY, NCR, Philippines
# Processing 176/939: MENDOZA, KASILAWAN, MAKATI CITY, NCR, Philippines
# Processing 177/939: P. DOMINGO, KASILAWAN, MAKATI CITY, NCR, Philippines
# Processing 178/939: P. NUNEZ, KASILAWAN, MAKATI CITY, NCR, Philippines
# Processing 179/939: PAGKAKAISA, KASILAWAN, MAKATI CITY, NCR, Philippines
# Processing 180/939: RODRIGUEZ, KASILAWAN, MAKATI CITY, NCR, Philippines
# Processing 181/939: A. SORIANO, LA PAZ, MAKATI CITY, NCR, Philippines
# Processing 182/939: ABC, LA PAZ, MAKATI CITY, NCR, Philippines
# Processing 183/939: ABCD, LA PAZ, MAKATI CITY, NCR, Philippines
# Processing 184/939: ARCHIMEDES, LA PAZ, MAKATI CITY, NCR, Philippines
# Processing 185/939: ARCHIMEDES, LA PAZ, MAKATI CITY, NCR, Philippines
# Processing 186/939: BALAGTAS, LA PAZ, MAKATI CITY, NCR, Philippines
# Processing 187/939: CABANILLAS, LA PAZ, MAKATI CITY, NCR, Philippines
# Processing 188/939: CATON, LA PAZ, MAKATI CITY, NCR, Philippines
# Processing 189/939: CATON, LA PAZ, MAKATI CITY, NCR, Philippines
# Processing 190/939: CERVERA, LA PAZ, MAKATI CITY, NCR, Philippines
# Processing 191/939: CHINO ROCES AVE (P.TAMO), LA PAZ, MAKATI CITY, NCR, Philippines
# Processing 192/939: CHINO ROCES AVE (P.TAMO), LA PAZ, MAKATI CITY, NCR, Philippines
# Processing 193/939: DAVILA, LA PAZ, MAKATI CITY, NCR, Philippines
# Processing 194/939: DUMAS, LA PAZ, MAKATI CITY, NCR, Philippines
# Processing 195/939: EUREKA, LA PAZ, MAKATI CITY, NCR, Philippines
# Processing 196/939: FLOR DE LIZ, LA PAZ, MAKATI CITY, NCR, Philippines
# Processing 197/939: GODET, LA PAZ, MAKATI CITY, NCR, Philippines
# Processing 198/939: GUAM, LA PAZ, MAKATI CITY, NCR, Philippines
# Processing 199/939: HAWAII, LA PAZ, MAKATI CITY, NCR, Philippines
# Processing 200/939: METROPOLITAN AVENUE, LA PAZ, MAKATI CITY, NCR, Philippines
# Processing 201/939: METROPOLITAN AVENUE, LA PAZ, MAKATI CITY, NCR, Philippines
# Processing 202/939: MOLA, LA PAZ, MAKATI CITY, NCR, Philippines
# Processing 203/939: ONYX, LA PAZ, MAKATI CITY, NCR, Philippines
# Processing 204/939: PASONG TIRAD, LA PAZ, MAKATI CITY, NCR, Philippines
# Processing 205/939: PRIMO DE RIVERA, LA PAZ, MAKATI CITY, NCR, Philippines
# Processing 206/939: PRIMO DE RIVERA, LA PAZ, MAKATI CITY, NCR, Philippines
# Processing 207/939: SUNRISE, LA PAZ, MAKATI CITY, NCR, Philippines
# Processing 208/939: PABLO OCAMPO (VITO CRUZ) EXTENSION, LA PAZ, MAKATI CITY, NCR, Philippines
# Processing 209/939: PABLO OCAMPO (VITO CRUZ) EXTENSION, LA PAZ, MAKATI CITY, NCR, Philippines
# Processing 210/939: PABLO OCAMPO (VITO CRUZ) EXTENSION, LA PAZ, MAKATI CITY, NCR, Philippines
# Processing 211/939: Z. ROXAS, LA PAZ, MAKATI CITY, NCR, Philippines
# Processing 212/939: Z. ROXAS, LA PAZ, MAKATI CITY, NCR, Philippines
# Processing 213/939: Danarra Condo, LA PAZ, MAKATI CITY, NCR, Philippines
# Processing 214/939: Danarra Condo, LA PAZ, MAKATI CITY, NCR, Philippines
# Processing 215/939: Danarra Condo, LA PAZ, MAKATI CITY, NCR, Philippines
# Processing 216/939: ONYX TOWNHOMES, LA PAZ, MAKATI CITY, NCR, Philippines
# Processing 217/939: ONYX TOWNHOMES, LA PAZ, MAKATI CITY, NCR, Philippines
# Processing 218/939: ONYX TOWNHOMES, LA PAZ, MAKATI CITY, NCR, Philippines
# Processing 219/939: AGAPITA COND. II, LA PAZ, MAKATI CITY, NCR, Philippines
# Processing 220/939: AGAPITA COND. II, LA PAZ, MAKATI CITY, NCR, Philippines
# Processing 221/939: ABEJA, OLYMPIA, MAKATI CITY, NCR, Philippines
# Processing 222/939: SAN ANSELMO (ANSELMO), OLYMPIA, MAKATI CITY, NCR, Philippines
# Processing 223/939: A. P. REYES, OLYMPIA, MAKATI CITY, NCR, Philippines
# Processing 224/939: A. P. REYES, OLYMPIA, MAKATI CITY, NCR, Philippines
# Processing 225/939: BANAHAW, OLYMPIA, MAKATI CITY, NCR, Philippines
# Processing 226/939: BARASAOIN / BARASOAIN, OLYMPIA, MAKATI CITY, NCR, Philippines
# Processing 227/939: BIAK NA BATO, OLYMPIA, MAKATI CITY, NCR, Philippines
# Processing 228/939: BINAKOD, OLYMPIA, MAKATI CITY, NCR, Philippines
# Processing 229/939: CHINO ROCES AVE (P. TAMO), OLYMPIA, MAKATI CITY, NCR, Philippines
# Processing 230/939: CHINO ROCES AVE (P. TAMO), OLYMPIA, MAKATI CITY, NCR, Philippines
# Processing 231/939: CALASAN, OLYMPIA, MAKATI CITY, NCR, Philippines
# Processing 232/939: COLMENA, OLYMPIA, MAKATI CITY, NCR, Philippines
# Processing 233/939: CONSTANCIA, OLYMPIA, MAKATI CITY, NCR, Philippines
# Processing 234/939: CONSTANCIA, OLYMPIA, MAKATI CITY, NCR, Philippines
# Processing 235/939: CORDILLERA, OLYMPIA, MAKATI CITY, NCR, Philippines
# Processing 236/939: ECONOMIA, OLYMPIA, MAKATI CITY, NCR, Philippines
# Processing 237/939: EMIN, OLYMPIA, MAKATI CITY, NCR, Philippines
# Processing 238/939: FORTUNA, OLYMPIA, MAKATI CITY, NCR, Philippines
# Processing 239/939: FORTUNA, OLYMPIA, MAKATI CITY, NCR, Philippines
# Processing 240/939: HERADURA, OLYMPIA, MAKATI CITY, NCR, Philippines
# Processing 241/939: HIPODROMO, OLYMPIA, MAKATI CITY, NCR, Philippines
# Processing 242/939: HIWAGA, OLYMPIA, MAKATI CITY, NCR, Philippines
# Processing 243/939: HONRADEZ, OLYMPIA, MAKATI CITY, NCR, Philippines
# Processing 244/939: HORMIGA, OLYMPIA, MAKATI CITY, NCR, Philippines
# Processing 245/939: IMUS, OLYMPIA, MAKATI CITY, NCR, Philippines
# Processing 246/939: INFANTA, OLYMPIA, MAKATI CITY, NCR, Philippines
# Processing 247/939: J. B. ROXAS, OLYMPIA, MAKATI CITY, NCR, Philippines
# Processing 248/939: J. B. ROXAS, OLYMPIA, MAKATI CITY, NCR, Philippines
# Processing 249/939: J. P. RIZAL, OLYMPIA, MAKATI CITY, NCR, Philippines
# Processing 250/939: J. P. RIZAL, OLYMPIA, MAKATI CITY, NCR, Philippines
# Processing 251/939: KAKARONG, OLYMPIA, MAKATI CITY, NCR, Philippines
# Processing 252/939: KAKARONG, OLYMPIA, MAKATI CITY, NCR, Philippines
# Processing 253/939: KALAYAAN AVE., OLYMPIA, MAKATI CITY, NCR, Philippines
# Processing 254/939: KALAYAAN AVE., OLYMPIA, MAKATI CITY, NCR, Philippines
# Processing 255/939: KALAYAAN AVE., OLYMPIA, MAKATI CITY, NCR, Philippines
# Processing 256/939: KALAYAAN AVE., OLYMPIA, MAKATI CITY, NCR, Philippines
# Processing 257/939: KAWIT, OLYMPIA, MAKATI CITY, NCR, Philippines
# Processing 258/939: LEGASPI, OLYMPIA, MAKATI CITY, NCR, Philippines
# Processing 259/939: LEGASPI, OLYMPIA, MAKATI CITY, NCR, Philippines
# Processing 260/939: LIWAYWAY, OLYMPIA, MAKATI CITY, NCR, Philippines
# Processing 261/939: MAKILING, OLYMPIA, MAKATI CITY, NCR, Philippines
# Processing 262/939: MALOLOS, OLYMPIA, MAKATI CITY, NCR, Philippines
# Processing 263/939: MAYON, OLYMPIA, MAKATI CITY, NCR, Philippines
# Processing 264/939: NOVALICHES, OLYMPIA, MAKATI CITY, NCR, Philippines
# Processing 265/939: OBRERO, OLYMPIA, MAKATI CITY, NCR, Philippines
# Processing 266/939: PATEROS, OLYMPIA, MAKATI CITY, NCR, Philippines
# Processing 267/939: PILILIA, OLYMPIA, MAKATI CITY, NCR, Philippines
# Processing 268/939: SACRAMENTO, OLYMPIA, MAKATI CITY, NCR, Philippines
# Processing 269/939: SAMAT, OLYMPIA, MAKATI CITY, NCR, Philippines
# Processing 270/939: SAMPAGUITA, OLYMPIA, MAKATI CITY, NCR, Philippines
# Processing 271/939: SAN ANSELMO, OLYMPIA, MAKATI CITY, NCR, Philippines
# Processing 272/939: SAN BERNARDINO, OLYMPIA, MAKATI CITY, NCR, Philippines
# Processing 273/939: SAN DIEGO, OLYMPIA, MAKATI CITY, NCR, Philippines
# Processing 274/939: SAN FRANCISCO, OLYMPIA, MAKATI CITY, NCR, Philippines
# Processing 275/939: SAN JACINTO, OLYMPIA, MAKATI CITY, NCR, Philippines
# Processing 276/939: SAN JOAQUIN, OLYMPIA, MAKATI CITY, NCR, Philippines
# Processing 277/939: SAN JOSE, OLYMPIA, MAKATI CITY, NCR, Philippines
# Processing 278/939: SAN MATEO, OLYMPIA, MAKATI CITY, NCR, Philippines
# Processing 279/939: SAN MAXIMO, OLYMPIA, MAKATI CITY, NCR, Philippines
# Processing 280/939: SAN MAXIMO, OLYMPIA, MAKATI CITY, NCR, Philippines
# Processing 281/939: SAN RAFAEL, OLYMPIA, MAKATI CITY, NCR, Philippines
# Processing 282/939: SOUTH AVENUE, OLYMPIA, MAKATI CITY, NCR, Philippines
# Processing 283/939: SANTA BARBARA, OLYMPIA, MAKATI CITY, NCR, Philippines
# Processing 284/939: SANTA LUCIA, OLYMPIA, MAKATI CITY, NCR, Philippines
# Processing 756/939: JORDAN, SANTA CRUZ, MAKATI CITY, NCR, Philippines
# Processing 757/939: JURADO, SANTA CRUZ, MAKATI CITY, NCR, Philippines
# Processing 758/939: JURADO, SANTA CRUZ, MAKATI CITY, NCR, Philippines
# Processing 759/939: KAKARONG, SANTA CRUZ, MAKATI CITY, NCR, Philippines
# Processing 760/939: KAKARONG, SANTA CRUZ, MAKATI CITY, NCR, Philippines
# Processing 761/939: KALAYAAN AVENUE, SANTA CRUZ, MAKATI CITY, NCR, Philippines
# Processing 762/939: KALAYAAN AVENUE, SANTA CRUZ, MAKATI CITY, NCR, Philippines
# Processing 763/939: KALAYAAN AVENUE, SANTA CRUZ, MAKATI CITY, NCR, Philippines
# Processing 764/939: MANCHAS, SANTA CRUZ, MAKATI CITY, NCR, Philippines
# Processing 765/939: MANCHAS, SANTA CRUZ, MAKATI CITY, NCR, Philippines
# Processing 766/939: MANDA, SANTA CRUZ, MAKATI CITY, NCR, Philippines
# Processing 767/939: MANDA, SANTA CRUZ, MAKATI CITY, NCR, Philippines
# Processing 768/939: MANGAHAS, SANTA CRUZ, MAKATI CITY, NCR, Philippines
# Processing 769/939: MANGAHAS, SANTA CRUZ, MAKATI CITY, NCR, Philippines
# Processing 770/939: MARTINEZ UNIDOS, SANTA CRUZ, MAKATI CITY, NCR, Philippines
# Processing 771/939: MARTINEZ UNIDOS, SANTA CRUZ, MAKATI CITY, NCR, Philippines
# Processing 772/939: MASCARDO, SANTA CRUZ, MAKATI CITY, NCR, Philippines
# Processing 773/939: MASCARDO, SANTA CRUZ, MAKATI CITY, NCR, Philippines
# Processing 774/939: METROPOLITAN AVENUE, SANTA CRUZ, MAKATI CITY, NCR, Philippines
# Processing 775/939: METROPOLITAN AVENUE, SANTA CRUZ, MAKATI CITY, NCR, Philippines
# Processing 776/939: METROPOLITAN AVENUE, SANTA CRUZ, MAKATI CITY, NCR, Philippines
# Processing 777/939: METROPOLITAN AVENUE, SANTA CRUZ, MAKATI CITY, NCR, Philippines
# Processing 778/939: MONTOJO, SANTA CRUZ, MAKATI CITY, NCR, Philippines
# Processing 779/939: MONTOJO, SANTA CRUZ, MAKATI CITY, NCR, Philippines
# Processing 780/939: PANAMA, SANTA CRUZ, MAKATI CITY, NCR, Philippines
# Processing 781/939: PANAMA, SANTA CRUZ, MAKATI CITY, NCR, Philippines
# Processing 782/939: PONTE, SANTA CRUZ, MAKATI CITY, NCR, Philippines
# Processing 783/939: PONTE, SANTA CRUZ, MAKATI CITY, NCR, Philippines
# Processing 784/939: SAN JUNIO, SANTA CRUZ, MAKATI CITY, NCR, Philippines
# Processing 785/939: SAN JUNIO, SANTA CRUZ, MAKATI CITY, NCR, Philippines
# Processing 786/939: SOUTH AVENUE, SANTA CRUZ, MAKATI CITY, NCR, Philippines
# Processing 787/939: SOUTH AVENUE, SANTA CRUZ, MAKATI CITY, NCR, Philippines
# Processing 788/939: SOUTH AVENUE, SANTA CRUZ, MAKATI CITY, NCR, Philippines
# Processing 789/939: SOLCHUAGA, SANTA CRUZ, MAKATI CITY, NCR, Philippines
# Processing 790/939: SOLCHUAGA, SANTA CRUZ, MAKATI CITY, NCR, Philippines
# Processing 791/939: SUEZ, SANTA CRUZ, MAKATI CITY, NCR, Philippines
# Processing 792/939: SUEZ, SANTA CRUZ, MAKATI CITY, NCR, Philippines
# Processing 793/939: VITO CRUZ EXTENSION/PABLO OCAMPO SR., SANTA CRUZ, MAKATI CITY, NCR, Philippines
# Processing 794/939: VITO CRUZ EXTENSION/PABLO OCAMPO SR., SANTA CRUZ, MAKATI CITY, NCR, Philippines
# Processing 795/939: VENECIA, SANTA CRUZ, MAKATI CITY, NCR, Philippines
# Processing 796/939: VENECIA, SANTA CRUZ, MAKATI CITY, NCR, Philippines
# Processing 797/939: VISITA, SANTA CRUZ, MAKATI CITY, NCR, Philippines
# Processing 798/939: VISITA, SANTA CRUZ, MAKATI CITY, NCR, Philippines
# Processing 799/939: YAGUE, SANTA CRUZ, MAKATI CITY, NCR, Philippines
# Processing 800/939: YAGUE, SANTA CRUZ, MAKATI CITY, NCR, Philippines
# Processing 801/939: ZAPOTE, SANTA CRUZ, MAKATI CITY, NCR, Philippines
# Processing 802/939: ZAPOTE, SANTA CRUZ, MAKATI CITY, NCR, Philippines
# Processing 803/939: BORMAHECO GARDEN HOMES, SANTA CRUZ, MAKATI CITY, NCR, Philippines
# Processing 804/939: BORMAHECO GARDEN HOMES, SANTA CRUZ, MAKATI CITY, NCR, Philippines
# Processing 805/939: BORMAHECO GARDEN HOMES, SANTA CRUZ, MAKATI CITY, NCR, Philippines
# Processing 806/939: BORMAHECO EXECUTIVE SUITES, SANTA CRUZ, MAKATI CITY, NCR, Philippines
# Processing 807/939: ZARAGOSA RESIDENCES, SANTA CRUZ, MAKATI CITY, NCR, Philippines
# Processing 808/939: ZARAGOSA RESIDENCES, SANTA CRUZ, MAKATI CITY, NCR, Philippines
# Processing 809/939: ZARAGOSA RESIDENCES, SANTA CRUZ, MAKATI CITY, NCR, Philippines
# Processing 810/939: CASA BOUGAINVILLE, SANTA CRUZ, MAKATI CITY, NCR, Philippines
# Processing 811/939: CASA BOUGAINVILLE, SANTA CRUZ, MAKATI CITY, NCR, Philippines
# Processing 812/939: CASA BOUGAINVILLE, SANTA CRUZ, MAKATI CITY, NCR, Philippines
# Processing 813/939: EUREKA SUITES, SANTA CRUZ, MAKATI CITY, NCR, Philippines
# Processing 814/939: EUREKA SUITES, SANTA CRUZ, MAKATI CITY, NCR, Philippines
# Processing 815/939: EUREKA SUITES, SANTA CRUZ, MAKATI CITY, NCR, Philippines
# Processing 816/939: GRACELAND PLACE CONDOMINIUM, SANTA CRUZ, MAKATI CITY, NCR, Philippines
# Processing 817/939: GRACELAND PLACE CONDOMINIUM, SANTA CRUZ, MAKATI CITY, NCR, Philippines
# Processing 818/939: GRACELAND PLACE CONDOMINIUM, SANTA CRUZ, MAKATI CITY, NCR, Philippines
# Processing 819/939: IDC CENTRE CONDOMINIUM, SANTA CRUZ, MAKATI CITY, NCR, Philippines
# Processing 820/939: IDC CENTRE CONDOMINIUM, SANTA CRUZ, MAKATI CITY, NCR, Philippines
# Processing 821/939: IDC CENTRE CONDOMINIUM, SANTA CRUZ, MAKATI CITY, NCR, Philippines
# Processing 822/939: IDC PLACE, SANTA CRUZ, MAKATI CITY, NCR, Philippines
# Processing 823/939: IDC PLACE, SANTA CRUZ, MAKATI CITY, NCR, Philippines
# Processing 824/939: IDC PLACE, SANTA CRUZ, MAKATI CITY, NCR, Philippines
# Processing 825/939: M SUITES, SANTA CRUZ, MAKATI CITY, NCR, Philippines
# Processing 826/939: M SUITES, SANTA CRUZ, MAKATI CITY, NCR, Philippines
# Processing 827/939: M SUITES, SANTA CRUZ, MAKATI CITY, NCR, Philippines
# Processing 828/939: A. P. REYES, TEJEROS, MAKATI CITY, NCR, Philippines
# Processing 829/939: A. P. REYES, TEJEROS, MAKATI CITY, NCR, Philippines
# Processing 830/939: ADORA, TEJEROS, MAKATI CITY, NCR, Philippines
# Processing 831/939: AGUILAR, TEJEROS, MAKATI CITY, NCR, Philippines
# Processing 832/939: ALMARIO, TEJEROS, MAKATI CITY, NCR, Philippines
# Processing 833/939: ALMAZAR, TEJEROS, MAKATI CITY, NCR, Philippines
# Processing 834/939: ARANDA, TEJEROS, MAKATI CITY, NCR, Philippines
# Processing 835/939: AURORA, TEJEROS, MAKATI CITY, NCR, Philippines
# Processing 836/939: BARON, TEJEROS, MAKATI CITY, NCR, Philippines
# Processing 837/939: BATUTE, TEJEROS, MAKATI CITY, NCR, Philippines
# Processing 838/939: C. SOTELO, TEJEROS, MAKATI CITY, NCR, Philippines
# Processing 839/939: CHINO ROCES, TEJEROS, MAKATI CITY, NCR, Philippines
# Processing 840/939: CHINO ROCES, TEJEROS, MAKATI CITY, NCR, Philippines
# Processing 841/939: CRISTOBAL, TEJEROS, MAKATI CITY, NCR, Philippines
# Processing 842/939: O. GOMEZ, TEJEROS, MAKATI CITY, NCR, Philippines
# Processing 843/939: DAVILA, TEJEROS, MAKATI CITY, NCR, Philippines
# Processing 844/939: EVANGELISTA, TEJEROS, MAKATI CITY, NCR, Philippines
# Processing 845/939: F. NAZARIO, TEJEROS, MAKATI CITY, NCR, Philippines
# Processing 846/939: H. CRUZ, TEJEROS, MAKATI CITY, NCR, Philippines
# Processing 847/939: H. SANTOS, TEJEROS, MAKATI CITY, NCR, Philippines
# Processing 848/939: H. SANTOS, TEJEROS, MAKATI CITY, NCR, Philippines
# Processing 849/939: IMELDA AVE (KALAYAAN), TEJEROS, MAKATI CITY, NCR, Philippines
# Processing 850/939: IMELDA AVE (KALAYAAN), TEJEROS, MAKATI CITY, NCR, Philippines
# Processing 851/939: J. P. RIZAL, TEJEROS, MAKATI CITY, NCR, Philippines
# Processing 852/939: J. P. RIZAL, TEJEROS, MAKATI CITY, NCR, Philippines
# Processing 853/939: J. P. RIZAL, TEJEROS, MAKATI CITY, NCR, Philippines
# Processing 854/939: MALOLOS, TEJEROS, MAKATI CITY, NCR, Philippines
# Processing 855/939: MASANGKAY, TEJEROS, MAKATI CITY, NCR, Philippines
# Processing 856/939: MASCARDO, TEJEROS, MAKATI CITY, NCR, Philippines
# Processing 857/939: MASUKOL, TEJEROS, MAKATI CITY, NCR, Philippines
# Processing 858/939: METROPOLITAN AVENUE, TEJEROS, MAKATI CITY, NCR, Philippines
# Processing 859/939: METROPOLITAN AVENUE, TEJEROS, MAKATI CITY, NCR, Philippines
# Processing 860/939: MONTOJO, TEJEROS, MAKATI CITY, NCR, Philippines
# Processing 861/939: P. AGUILAR, TEJEROS, MAKATI CITY, NCR, Philippines
# Processing 862/939: P. RIVERA, TEJEROS, MAKATI CITY, NCR, Philippines
# Processing 863/939: P. RIVERA, TEJEROS, MAKATI CITY, NCR, Philippines
# Processing 864/939: P. VARONA, TEJEROS, MAKATI CITY, NCR, Philippines
# Processing 865/939: PASONG TIRAD, TEJEROS, MAKATI CITY, NCR, Philippines
# Processing 866/939: PONTE, TEJEROS, MAKATI CITY, NCR, Philippines
# Processing 867/939: SANDICO, TEJEROS, MAKATI CITY, NCR, Philippines
# Processing 868/939: SOLCHUAGA, TEJEROS, MAKATI CITY, NCR, Philippines
# Processing 869/939: SOLITA, TEJEROS, MAKATI CITY, NCR, Philippines
# Processing 870/939: TELLA, TEJEROS, MAKATI CITY, NCR, Philippines
# Processing 871/939: YAGUE, TEJEROS, MAKATI CITY, NCR, Philippines
# Processing 872/939: MAKATI TERRACES CONDO, TEJEROS, MAKATI CITY, NCR, Philippines
# Processing 873/939: MAKATI TERRACES CONDO, TEJEROS, MAKATI CITY, NCR, Philippines
# Processing 874/939: MAKATI TERRACES CONDO, TEJEROS, MAKATI CITY, NCR, Philippines
# Processing 875/939: THE CELERIO, TEJEROS, MAKATI CITY, NCR, Philippines
# Processing 876/939: THE CELERIO, TEJEROS, MAKATI CITY, NCR, Philippines
# Processing 877/939: THE CELERIO, TEJEROS, MAKATI CITY, NCR, Philippines
# Processing 878/939: CALIZO-SOLANO CONDOMINIUM, TEJEROS, MAKATI CITY, NCR, Philippines
# Processing 879/939: CALIZO-SOLANO CONDOMINIUM, TEJEROS, MAKATI CITY, NCR, Philippines
# Processing 880/939: CALIZO-SOLANO CONDOMINIUM, TEJEROS, MAKATI CITY, NCR, Philippines
# Processing 881/939: A. BONIFACIO, VALENZUELA, MAKATI CITY, NCR, Philippines
# Processing 882/939: ANTIPOLO, VALENZUELA, MAKATI CITY, NCR, Philippines
# Processing 883/939: ANTIPOLO, VALENZUELA, MAKATI CITY, NCR, Philippines
# Processing 884/939: ASUNCION, VALENZUELA, MAKATI CITY, NCR, Philippines
# Processing 885/939: BALER, VALENZUELA, MAKATI CITY, NCR, Philippines
# Processing 886/939: CANDELARIA, VALENZUELA, MAKATI CITY, NCR, Philippines
# Processing 887/939: CONCEPCION, VALENZUELA, MAKATI CITY, NCR, Philippines
# Processing 888/939: D. OLIMAN, VALENZUELA, MAKATI CITY, NCR, Philippines
# Processing 889/939: HORMIGA, VALENZUELA, MAKATI CITY, NCR, Philippines
# Processing 890/939: IRIGA, VALENZUELA, MAKATI CITY, NCR, Philippines
# Processing 891/939: J. P. RIZAL, VALENZUELA, MAKATI CITY, NCR, Philippines
# Processing 892/939: J. P. RIZAL, VALENZUELA, MAKATI CITY, NCR, Philippines
# Processing 893/939: KALAYAAN AVENUE, VALENZUELA, MAKATI CITY, NCR, Philippines
# Processing 894/939: KALAYAAN AVENUE, VALENZUELA, MAKATI CITY, NCR, Philippines
# Processing 895/939: LEGASPI, VALENZUELA, MAKATI CITY, NCR, Philippines
# Processing 896/939: LEGASPI, VALENZUELA, MAKATI CITY, NCR, Philippines
# Processing 897/939: MILAGROS, VALENZUELA, MAKATI CITY, NCR, Philippines
# Processing 898/939: N. GARCIA (REPOSO), VALENZUELA, MAKATI CITY, NCR, Philippines
# Processing 899/939: N. GARCIA (REPOSO), VALENZUELA, MAKATI CITY, NCR, Philippines
# Processing 900/939: OBRERO, VALENZUELA, MAKATI CITY, NCR, Philippines
# Processing 901/939: PATEROS, VALENZUELA, MAKATI CITY, NCR, Philippines
# Processing 902/939: PENAFRANCIA, VALENZUELA, MAKATI CITY, NCR, Philippines
# Processing 903/939: PILILIA, VALENZUELA, MAKATI CITY, NCR, Philippines
# Processing 904/939: S. OSMENA, VALENZUELA, MAKATI CITY, NCR, Philippines
# Processing 905/939: S. OSMENA, VALENZUELA, MAKATI CITY, NCR, Philippines
# Processing 906/939: TAGUIG, VALENZUELA, MAKATI CITY, NCR, Philippines
# Processing 907/939: TANAY, VALENZUELA, MAKATI CITY, NCR, Philippines
# Processing 908/939: TERESA, VALENZUELA, MAKATI CITY, NCR, Philippines
# Processing 909/939: BONAVENTURES GARDEN, VALENZUELA, MAKATI CITY, NCR, Philippines
# Processing 910/939: BONAVENTURES GARDEN, VALENZUELA, MAKATI CITY, NCR, Philippines
# Processing 911/939: CARMEN CONDOMINIUM, VALENZUELA, MAKATI CITY, NCR, Philippines
# Processing 912/939: CARMEN CONDOMINIUM, VALENZUELA, MAKATI CITY, NCR, Philippines
# Processing 913/939: CARMEN CONDOMINIUM, VALENZUELA, MAKATI CITY, NCR, Philippines
# Processing 914/939: COLONEL CONDOMINIUM II, VALENZUELA, MAKATI CITY, NCR, Philippines
# Processing 915/939: COLONEL CONDOMINIUM II, VALENZUELA, MAKATI CITY, NCR, Philippines
# Processing 916/939: COLONEL CONDOMINIUM II, VALENZUELA, MAKATI CITY, NCR, Philippines
# Processing 917/939: LONAL CONDOMINIUM, VALENZUELA, MAKATI CITY, NCR, Philippines
# Processing 918/939: LONAL CONDOMINIUM, VALENZUELA, MAKATI CITY, NCR, Philippines
# Processing 919/939: LONAL CONDOMINIUM, VALENZUELA, MAKATI CITY, NCR, Philippines
# Processing 920/939: QUESTAR CONDO, VALENZUELA, MAKATI CITY, NCR, Philippines
# Processing 921/939: QUESTAR CONDO, VALENZUELA, MAKATI CITY, NCR, Philippines
# Processing 922/939: QUESTAR CONDO, VALENZUELA, MAKATI CITY, NCR, Philippines
# Processing 923/939: ST. DAVID SQUARE, VALENZUELA, MAKATI CITY, NCR, Philippines
# Processing 924/939: ST. DAVID SQUARE, VALENZUELA, MAKATI CITY, NCR, Philippines
# Processing 925/939: CITYLAND VIII*, PIO DEL PILAR, MAKATI CITY, NCR, Philippines
# Processing 926/939: CITYLAND VIII*, PIO DEL PILAR, MAKATI CITY, NCR, Philippines
# Processing 927/939: CITYLAND VIII*, PIO DEL PILAR, MAKATI CITY, NCR, Philippines
# Processing 928/939: MAKATI EXECUTIVE TOWER III*, PIO DEL PILAR, MAKATI CITY, NCR, Philippines
# Processing 929/939: MAKATI EXECUTIVE TOWER III*, PIO DEL PILAR, MAKATI CITY, NCR, Philippines
# Processing 930/939: MAKATI EXECUTIVE TOWER III*, PIO DEL PILAR, MAKATI CITY, NCR, Philippines
# Processing 931/939: ONE HUNDRED WEST*, PIO DEL PILAR, MAKATI CITY, NCR, Philippines
# Processing 932/939: ONE HUNDRED WEST*, PIO DEL PILAR, MAKATI CITY, NCR, Philippines
# Processing 933/939: ONE HUNDRED WEST*, PIO DEL PILAR, MAKATI CITY, NCR, Philippines
# Processing 934/939: WEST OF AYALA, PIO DEL PILAR, MAKATI CITY, NCR, Philippines
# Processing 935/939: WEST OF AYALA, PIO DEL PILAR, MAKATI CITY, NCR, Philippines
# Processing 936/939: WEST OF AYALA, PIO DEL PILAR, MAKATI CITY, NCR, Philippines
# Processing 937/939: BURGUNDY CORP. TOWER*, PIO DEL PILAR, MAKATI CITY, NCR, Philippines
# Processing 938/939: BURGUNDY CORP. TOWER*, PIO DEL PILAR, MAKATI CITY, NCR, Philippines
# Processing 939/939: BURGUNDY CORP. TOWER*, PIO DEL PILAR, MAKATI CITY, NCR, Philippines

# %%
# Convert results to DataFrame and merge with original data
results_df = pd.DataFrame(results)
output_df = pd.concat([df, results_df], axis=1)

# %%
# Display sample results
print("\nSample of processed data:")
output_df.head(5)
# Out:
# Sample of processed data:
#   Province City/Municipality Barangay Street/Subdivision  \
# 0      NCR       MAKATI CITY  BEL-AIR            AMAPOLA
# 1      NCR       MAKATI CITY  BEL-AIR            ANTARES
# 2      NCR       MAKATI CITY  BEL-AIR               ANZA
# 3      NCR       MAKATI CITY  BEL-AIR           AQUARIUS
# 4      NCR       MAKATI CITY  BEL-AIR              ARIES
#
#                 Vicinity Classification    ZV/SQM  \
# 0    Estrella - Mercedes             RR  250000.0
# 1     Jupiter - Mercedes             RR  250000.0
# 2  Makati Ave. - Polaris             CR  350000.0
# 3          Hydra - Solar             RR  250000.0
# 4      Mercedes - Taurus             RR  250000.0
#
#                                    original_address   latitude   longitude  \
# 0   AMAPOLA, BEL-AIR, MAKATI CITY, NCR, Philippines  14.562833  121.037264
# 1   ANTARES, BEL-AIR, MAKATI CITY, NCR, Philippines  14.558207  121.034377
# 2      ANZA, BEL-AIR, MAKATI CITY, NCR, Philippines  14.562393  121.028610
# 3  AQUARIUS, BEL-AIR, MAKATI CITY, NCR, Philippines  14.561553  121.036326
# 4     ARIES, BEL-AIR, MAKATI CITY, NCR, Philippines  14.562170  121.036327
#
#           h3_index                         google_formatted_address  \
# 0  89694ec0e4bffff  Amapola, Makati, Kalakhang Maynila, Philippines
# 1  89694ec1d8fffff       Antares, Makati, Metro Manila, Philippines
# 2  89694ec032bffff          Anza, Makati, Metro Manila, Philippines
# 3  89694ec0e4bffff      Aquarius, Makati, Metro Manila, Philippines
# 4  89694ec0e4bffff         Aries, Makati, Metro Manila, Philippines
#
#                                      google_place_id google_location_type
# 0  Ei9BbWFwb2xhLCBNYWthdGksIEthbGFraGFuZyBNYXluaW...     GEOMETRIC_CENTER
# 1                        ChIJ-c7pNv7IlzMR0gWibCBQkZs     GEOMETRIC_CENTER
# 2                        ChIJCeHlCKrJlzMRYt2_0QtgBFY     GEOMETRIC_CENTER
# 3  EitBcXVhcml1cywgTWFrYXRpLCBNZXRybyBNYW5pbGEsIF...     GEOMETRIC_CENTER
# 4                        ChIJ-XnUe1XIlzMRYoMIuFoH5m0     GEOMETRIC_CENTER

# %%
# Save results to Excel
output_file = f"geocoded_addresses_{datetime.now().strftime('%Y%m%d_%H%M%S')}.xlsx"
output_df.to_excel(output_file, index=False)
print(f"\nProcessing complete. Results saved to {output_file}")

# %%
# Optional: Basic analysis of results
print("\nProcessing Summary:")
print(f"Total addresses processed: {len(output_df)}")
print(f"Successful geocoding: {output_df['latitude'].notna().sum()}")
print(f"Failed geocoding: {output_df['latitude'].isna().sum()}")
# Out:
# Processing Summary:
# Total addresses processed: 939
# Successful geocoding: 939
# Failed geocoding: 0

# %%
# Optional: Display unique location types
if 'google_location_type' in output_df.columns:
    print("\nLocation type distribution:")
    print(output_df['google_location_type'].value_counts())
# Out:
# Location type distribution:
# google_location_type
# GEOMETRIC_CENTER      640
# ROOFTOP               220
# APPROXIMATE            76
# RANGE_INTERPOLATED      3
# Name: count, dtype: int64

# %% [markdown]
# # Geocoding Viz

# %%
import pandas as pd
import folium
import h3
import json
import numpy as np
from branca.colormap import LinearColormap

def h3_hexagon_to_coordinates(h3_address):
    """Convert H3 address to coordinates for plotting"""
    boundary = h3.cell_to_boundary(h3_address)
    return [[coord[0], coord[1]] for coord in boundary]

# Read and clean the data
df = output_df

# Clean and convert ZV/SQM to numeric, handling any non-numeric values
df['ZV/SQM'] = pd.to_numeric(df['ZV/SQM'], errors='coerce')

# Remove any rows where ZV/SQM is NaN
df = df.dropna(subset=['ZV/SQM'])

# Sort the values to ensure proper color mapping
df = df.sort_values('ZV/SQM')

# Create a base map centered on Makati
center_lat = df['latitude'].mean()
center_lng = df['longitude'].mean()
m = folium.Map(location=[center_lat, center_lng], zoom_start=14)

# Create color map based on quantiles for better distribution
q_25 = df['ZV/SQM'].quantile(0.25)
q_50 = df['ZV/SQM'].quantile(0.50)
q_75 = df['ZV/SQM'].quantile(0.75)
max_value = df['ZV/SQM'].max()

colormap = LinearColormap(
    colors=['#fee5d9', '#fcae91', '#fb6a4a', '#cb181d'],
    vmin=df['ZV/SQM'].min(),
    vmax=max_value,
    caption='Zone Value per Square Meter (PHP)'
)

# Create a dictionary to store hexagons by H3 index to avoid duplicates
hexagon_dict = {}

# Process each row
for idx, row in df.iterrows():
    try:
        # Get hexagon coordinates
        hex_coordinates = h3_hexagon_to_coordinates(row['h3_index'])
        
        # Store the highest ZV/SQM value for each hexagon
        # TODO: ask if highest or average
        if row['h3_index'] not in hexagon_dict or hexagon_dict[row['h3_index']]['value'] < row['ZV/SQM']:
            hexagon_dict[row['h3_index']] = {
                'coordinates': hex_coordinates,
                'value': row['ZV/SQM'],
                'popup_text': f"""
                Address: {row['google_formatted_address']}<br>
                Zone Value: ₱{row['ZV/SQM']:,.2f}/sqm<br>
                """
            }
    except Exception as e:
        print(f"Error processing row {idx}: {str(e)}")

# Add hexagons to the map
for h3_index, data in hexagon_dict.items():
    try:
        # Calculate color based on ZV/SQM
        norm_value = (data['value'] - df['ZV/SQM'].min()) / (max_value - df['ZV/SQM'].min())
        color = colormap(data['value'])
        
        # Add polygon to map
        folium.Polygon(
            locations=data['coordinates'],
            color='black',
            weight=1,
            fill=True,
            fill_color=color,
            fill_opacity=0.7,
            popup=data['popup_text']
        ).add_to(m)
    except Exception as e:
        print(f"Error adding hexagon {h3_index}: {str(e)}")

# Add the colormap to the map
colormap.add_to(m)

# Save the map
m.save('makati_zoning_map.html')

# Print statistics
print("\nZone Value Statistics:")
print(df['ZV/SQM'].describe())

print("\nValue Ranges:")
print(f"0-25th percentile: ₱{q_25:,.2f}/sqm")
print(f"25-50th percentile: ₱{q_50:,.2f}/sqm")
print(f"50-75th percentile: ₱{q_75:,.2f}/sqm")
print(f"75-100th percentile: ₱{max_value:,.2f}/sqm")

print("\nClassification Distribution:")
print(df['Classification'].value_counts())
# Out:
# Zone Value Statistics:
# count       926.000000
# mean     152545.896328
# std       73678.209580
# min       38500.000000
# 25%      100000.000000
# 50%      130000.000000
# 75%      180000.000000
# max      500000.000000
# Name: ZV/SQM, dtype: float64
#
# Value Ranges:
# 0-25th percentile: ₱100,000.00/sqm
# 25-50th percentile: ₱130,000.00/sqm
# 50-75th percentile: ₱180,000.00/sqm
# 75-100th percentile: ₱500,000.00/sqm
#
# Classification Distribution:
# Classification
# RR    366
# CR    177
# PS    127
# RC    120
# CC    115
# X      19
# I       2
# Name: count, dtype: int64

# %%
display(m)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_56b35a6934d106dd5f991576bd63328e {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/d3/3.5.5/d3.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_56b35a6934d106dd5f991576bd63328e&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_56b35a6934d106dd5f991576bd63328e = L.map(
#                 &quot;map_56b35a6934d106dd5f991576bd63328e&quot;,
#                 {
#                     center: [14.409755939524839, 121.12053552861771],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 14,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_009baad68562d5a5f748bd8fdb655aa1 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_009baad68562d5a5f748bd8fdb655aa1.addTo(map_56b35a6934d106dd5f991576bd63328e);
#
#
#             var polygon_fe13269b445ac1ad23e0079652691ad8 = L.polygon(
#                 [[14.571984543297702, 121.0239531205755], [14.570186296271093, 121.02429715182825], [14.569663328852144, 121.02604676715283], [14.570938635409412, 121.02745237785545], [14.572736907061811, 121.02710834347761], [14.573259847531444, 121.02535870152171]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;black&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#fdbaa0ff&quot;, &quot;fillOpacity&quot;: 0.7, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 1.0, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 1}
#             ).addTo(map_56b35a6934d106dd5f991576bd63328e);
#
#
#         var popup_c949106a7f94d64c21910096a50ddeff = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_e7457229921621c7ca098c3f607d29e0 = $(`&lt;div id=&quot;html_e7457229921621c7ca098c3f607d29e0&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;                 Address: Antipolo, Makati, Metro Manila, Philippines&lt;br&gt;                 Zone Value: ₱160,000.00/sqm&lt;br&gt;                 &lt;/div&gt;`)[0];
#                 popup_c949106a7f94d64c21910096a50ddeff.setContent(html_e7457229921621c7ca098c3f607d29e0);
#
#
#
#         polygon_fe13269b445ac1ad23e0079652691ad8.bindPopup(popup_c949106a7f94d64c21910096a50ddeff)
#         ;
#
#
#
#
#             var polygon_3e745e6ebfc1c983b810be244e7b3a4d = L.polygon(
#                 [[14.566653853616307, 121.01342674384348], [14.564855653046646, 121.0137707631888], [14.564332727100721, 121.01552018085127], [14.565608028686087, 121.01692560580607], [14.567406253898252, 121.01658158332879], [14.567929152882837, 121.01483213902817]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;black&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#fc896bff&quot;, &quot;fillOpacity&quot;: 0.7, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 1.0, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 1}
#             ).addTo(map_56b35a6934d106dd5f991576bd63328e);
#
#
#         var popup_cead4c990e2a0b9cad39c7536d205a42 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_4769d34ff79f1075b19ab7bafb6e6593 = $(`&lt;div id=&quot;html_4769d34ff79f1075b19ab7bafb6e6593&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;                 Address: Metropolitan Ave, Makati, Metro Manila, Philippines&lt;br&gt;                 Zone Value: ₱275,000.00/sqm&lt;br&gt;                 &lt;/div&gt;`)[0];
#                 popup_cead4c990e2a0b9cad39c7536d205a42.setContent(html_4769d34ff79f1075b19ab7bafb6e6593);
#
#
#
#         polygon_3e745e6ebfc1c983b810be244e7b3a4d.bindPopup(popup_cead4c990e2a0b9cad39c7536d205a42)
#         ;
#
#
#
#
#             var polygon_34b99d00c8bbb2cd6439818fa79e669c = L.polygon(
#                 [[14.568222409577468, 121.00817866943244], [14.566424285744128, 121.0085226850288], [14.565901432368717, 121.01027201527502], [14.567176729794935, 121.01167735656622], [14.5689748782755, 121.01133333783443], [14.569497704682865, 121.00958398094636]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;black&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#fdbaa0ff&quot;, &quot;fillOpacity&quot;: 0.7, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round

# %%
def h3_hexagon_to_coordinates(h3_address):
    """Convert H3 address to coordinates for plotting"""
    boundary = h3.cell_to_boundary(h3_address)
    # Folium expects coordinates in lat,lng format
    return [[coord[0], coord[1]] for coord in boundary]

# %%
output_df['ZV/SQM'] = pd.to_numeric(output_df['ZV/SQM'], errors='coerce')

# %%
# Create a base map centered on Makati
center_lat = output_df['latitude'].mean()
center_lng = output_df['longitude'].mean()
m = folium.Map(location=[center_lat, center_lng], zoom_start=14)

# %%
# Create color map based on ZV/SQM
min_value = output_df['ZV/SQM'].min()
max_value = output_df['ZV/SQM'].max()
colormap = LinearColormap(
    colors=['yellow', 'orange', 'red'],
    vmin=min_value,
    vmax=max_value,
    caption='Zone Value per Square Meter (PHP)'
)

# %%
# Add hexagons to the map
for idx, row in output_df.iterrows():
    # Get hexagon coordinates
    hex_coordinates = h3_hexagon_to_coordinates(row['h3_index'])
    
    # Calculate color based on ZV/SQM
    color = colormap(row['ZV/SQM'])
    
    # Create popup text
    popup_text = f"""
    Address: {row['google_formatted_address']}<br>
    Zone Value: ₱{row['ZV/SQM']:,.2f}/sqm<br>
    Classification: {row['Classification']}<br>
    Barangay: {row['Barangay']}<br>
    """
    
    # Add polygon to map
    folium.Polygon(
        locations=hex_coordinates,
        color='black',
        weight=1,
        fill=True,
        fill_color=color,
        fill_opacity=0.7,
        popup=popup_text
    ).add_to(m)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[32], line 7
#       4 hex_coordinates = h3_hexagon_to_coordinates(row['h3_index'])
#       6 # Calculate color based on ZV/SQM
# ----> 7 color = colormap(row['ZV/SQM'])
#       9 # Create popup text
#      10 popup_text = f"""
#      11 Address: {row['google_formatted_address']}<br>
#      12 Zone Value: ₱{row['ZV/SQM']:,.2f}/sqm<br>
#      13 Classification: {row['Classification']}<br>
#      14 Barangay: {row['Barangay']}<br>
#      15 """
#
# File C:\AC_Analytics\BIR_Zonal_Files\.venv\Lib\site-packages\branca\colormap.py:184, in ColorMap.__call__(self, x)
#     180 def __call__(self, x: float) -> str:
#     181     """Provides the color corresponding to value `x` in the
#     182     form of a string of hexadecimal values "#RRGGBBAA".
#     183     """
# --> 184     return self.rgba_hex_str(x)
#
# File C:\AC_Analytics\BIR_Zonal_Files\.venv\Lib\site-packages\branca\colormap.py:178, in ColorMap.rgba_hex_str(self, x)
#     174 def rgba_hex_str(self, x: float) -> str:
#     175     """Provides the color corresponding to value `x` in the
#     176     form of a string of hexadecimal values "#RRGGBBAA".
#     177     """
# --> 178     return "#%02x%02x%02x%02x" % self.rgba_bytes_tuple(x)
#
# File C:\AC_Analytics\BIR_Zonal_Files\.venv\Lib\site-packages\branca\colormap.py:160, in ColorMap.rgba_bytes_tuple(self, x)
#     156 def rgba_bytes_tuple(self, x: float) -> TypeRGBAInts:
#     157     """Provides the color corresponding to value `x` in the
#     158     form of a tuple (R,G,B,A) with int values between 0 and 255.
#     159     """
# --> 160     return tuple(_color_float_to_int(u) for u in self.rgba_floats_tuple(x))
#
# File C:\AC_Analytics\BIR_Zonal_Files\.venv\Lib\site-packages\branca\colormap.py:325, in LinearColormap.rgba_floats_tuple(self, x)
#     323     p = 1.0
#     324 else:
# --> 325     raise ValueError("Thresholds are not sorted.")
#     327 return tuple(  # type: ignore
#     328     (1.0 - p) * self.colors[i - 1][j] + p * self.colors[i][j] for j in range(4)
#     329 )
#
# ValueError: Thresholds are not sorted.

# %%
# Add the colormap to the map
colormap.add_to(m)

# %%
# Save the map
m.save('makati_zoning_map.html')

# Optional: Display some statistics about the zones
print("\nZone Value Statistics:")
print(output_df['ZV/SQM'].describe())

print("\nClassification Distribution:")
print(output_df['Classification'].value_counts())
